# %%
data = [
    {
    "name": "example",
    "spo": {
        "yes": 100,
        "no": 50,
        "abstain": 25
    },
    "drep" : {
        "yes": 0.6,
        "no": 0.3,
        "no confidance": 0.1,
        "not voted": 0.0,

        "abstain": 0.1
    },
    "cc": {
        "yes": 0.7,
        "no": 0.2,
        "abstain": 0.1
    },
}, {"name": "example2",
    "spo": {
        "yes": 100,
        "no": 50,
        "abstain": 25
    },
    "drep" : {
        "yes": 0.6,
        "no": 0.3,
        "no confidance": 0.1,
        "not voted": 0.0,
        "abstain": 0.1
    },
    "cc": {
        "yes": 0.7,
        "no": 0.2,
        "abstain": 0.1
    }}]
